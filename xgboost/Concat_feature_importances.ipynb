# %% [markdown]
# # Concat feature importances
#
# Running xgboost multiple times results in different sets of feature importances (all uniquely saved in feature_importances), probably due to the randomness and greedyness of the algorithm. However, some feaures will be important in multiple runs, and these are the features that I think are the most important.
#
# So this notebook concatenates multiple feature_importance files into one file that has information about the feature importances and the number of times a feature was found to be important

# %%
# Want to combine into a dataframe with columns: feature, importances (a list), count (yes count is just the length of importances but it might be handy to just have this as a redundant column)

cancer_types = ['BLCA', 'BRCA', 'COAD', 'ESCA', 'HNSC', 'KIRC', 'KIRP', 'LIHC', 'LUAD', 'LUSC', 'PRAD', 'THCA', 'UCEC']
# cancer_type = '' # for multiclass

for cancer_type in cancer_types:
    # read in feature importance files
    import os
    file_names = os.listdir('feature_importances/')
    file_names = [file for file in file_names if cancer_type+'_run_' in file]
    print("Reading in files " , file_names)

    import pandas as pd
    all_importances = pd.DataFrame(columns=['feature', 'importances', 'count'])

    # go through all files and add importances to all_importances
    for file_name in file_names:
        with open('feature_importances/'+file_name) as file:
            lines = file.readlines()
        for line in lines:
            values = line.split(',')

            # get feature and importance
            feature = int(values[0].split(':')[1][1:])
            importance = float(values[1].split(':')[1][1:])

            # add to pandas df
    #         print("feature ", feature, " in all importances: ", feature in all_importances["feature"].values)
            if feature in all_importances["feature"].values: 
                # add to list and increase count
                row_index = all_importances.loc[all_importances['feature'] == feature].index.values[0] # find row index with this feature
                all_importances["importances"][row_index] = all_importances["importances"][row_index] + [importance] # add importances to list
                all_importances["count"][row_index] = all_importances["count"][row_index] + 1 # add 1 to count
            else:
                all_importances = all_importances.append({"feature":feature, "importances":[importance], "count":1}, ignore_index=True)

    all_importances = all_importances.sort_values(by = 'count', ascending = False)
    print(all_importances)

    # save file
    all_importances.to_csv('feature_importances/'+cancer_type+'_concatenated.csv', index=False)
# Out:
# Reading in files  ['BLCA_run_3.csv', 'BLCA_run_6.csv', 'BLCA_run_0.csv', 'BLCA_run_4.csv', 'BLCA_run_5.csv', 'BLCA_run_7.csv', 'BLCA_run_1.csv', 'BLCA_run_2.csv']
#     feature                          importances count
# 17   215686  [0.04211, 0.0147, 0.01773, 0.02576]     4
# 9     77064  [0.03419, 0.04288, 0.0522, 0.00713]     4
# 16   185000           [0.1398, 0.05291, 0.05652]     3
# 54   230575             [0.1133, 0.0929, 0.3074]     3
# 47   114530          [0.06221, 0.07588, 0.17003]     3
# ..      ...                                  ...   ...
# 56        1                            [0.00263]     1
# 53   206040                            [0.02492]     1
# 51   158344                            [0.00714]     1
# 50   154647                            [0.00331]     1
# 153  244282                            [0.08188]     1
#
# [154 rows x 3 columns]
# Reading in files  ['BRCA_run_0.csv', 'BRCA_run_1.csv', 'BRCA_run_3.csv', 'BRCA_run_5.csv', 'BRCA_run_7.csv', 'BRCA_run_6.csv', 'BRCA_run_4.csv', 'BRCA_run_2.csv']
#     feature                                        importances count
# 13   112353  [0.27419, 0.08043, 0.11683, 0.07993, 0.10862, ...     7
# 20   165611  [0.25204, 0.10758, 0.26506, 0.35196, 0.1855, 0...     6
# 6     33250  [0.0212, 0.01046, 0.00263, 0.03711, 0.00825, 0...     6
# 43   114335       [0.02119, 0.17991, 0.02675, 0.0986, 0.02488]     5
# 21   169532      [0.00726, 0.00461, 0.00489, 0.10354, 0.00372]     5
# ..      ...                                                ...   ...
# 94    43904                                          [0.00372]     1
# 95    46542                                          [0.00998]     1
# 97    52671                                          [0.00554]     1
# 98    53837                                          [0.00905]     1
# 220  256421                                          [0.01513]     1
#
# [221 rows x 3 columns]
# Reading in files  ['COAD_run_5.csv', 'COAD_run_4.csv', 'COAD_run_0.csv', 'COAD_run_1.csv', 'COAD_run_2.csv', 'COAD_run_7.csv', 'COAD_run_3.csv', 'COAD_run_6.csv']
#    feature                  importances count
# 12    8649    [0.0727, 0.0727, 0.81825]     3
# 20   12674      [0.81825, 0.81825, 1.0]     3
# 19    6970     [0.0727, 0.0727, 0.0727]     3
# 17     496  [0.04471, 0.04471, 0.04471]     3
# 18     759           [0.02962, 0.05227]     2
# 25   71382                    [0.01435]     1
# 27     283                    [0.04471]     1
# 28    2673                    [0.02037]     1
# 29   17202                    [0.02962]     1
# 30   47380                    [0.01434]     1
# 31    3840                    [0.04234]     1
# 32    5648                    [0.03461]     1
# 0     1382                    [0.05227]     1
# 33    6767                    [0.06601]     1
# 34   27941                    [0.02378]     1
# 35   38232                    [0.01991]     1
# 36   57453                    [0.02859]     1
# 37  111756                    [0.01676]     1
# 38  135454                    [0.68946]     1
# 39  136051                     [0.0142]     1
# 40  255007                    [0.01208]     1
# 41   14553                    [0.02037]     1
# 42   83654                    [0.02962]     1
# 26  112984                    [0.02037]     1
# 22  188762                    [0.01435]     1
# 24   31205                    [0.81825]     1
# 9   189895                     [0.0199]     1
# 2     6472                    [0.04234]     1
# 3    31977                    [0.68945]     1
# 4    50769                    [0.02858]     1
# 5    94075                    [0.02378]     1
# 6   113152                    [0.03462]     1
# 7   160051                    [0.01676]     1
# 8   174004                     [0.0142]     1
# 10  251328                    [0.01208]     1
# 23    6645                    [0.02962]     1
# 11     625                    [0.04471]     1
# 13   24410                    [0.81825]     1
# 14   81214                    [0.01435]     1
# 15  109334                    [0.02962]     1
# 16  175519                    [0.02037]     1
# 21   40603                    [0.02037]     1
# 1     6095                    [0.06601]     1
# 43  252494                    [0.01435]     1
# Reading in files  ['ESCA_run_3.csv', 'ESCA_run_4.csv', 'ESCA_run_1.csv', 'ESCA_run_0.csv', 'ESCA_run_6.csv', 'ESCA_run_5.csv', 'ESCA_run_2.csv', 'ESCA_run_7.csv']
#     feature                                        importances count
# 31   175047  [0.08592, 0.05039, 0.21551, 0.02411, 0.07303, ...     6
# 32   211805      [0.43092, 0.31276, 0.13949, 0.15752, 0.19827]     5
# 18   260204      [0.34059, 0.35639, 0.06416, 0.29933, 0.35772]     5
# 7     10365               [0.00905, 0.03602, 0.07888, 0.02015]     4
# 23      152               [0.05623, 0.02557, 0.04778, 0.04118]     4
# ..      ...                                                ...   ...
# 46      664                                          [0.03874]     1
# 44      147                                          [0.00129]     1
# 42   174397                                          [0.00615]     1
# 40   111345                                          [0.08806]     1
# 110  265396                                          [0.03542]     1
#
# [111 rows x 3 columns]
# Reading in files  ['HNSC_run_6.csv', 'HNSC_run_5.csv', 'HNSC_run_2.csv', 'HNSC_run_7.csv', 'HNSC_run_1.csv', 'HNSC_run_0.csv', 'HNSC_run_4.csv', 'HNSC_run_3.csv']
#     feature                                        importances count
# 10    82124  [0.27414, 0.27016, 0.12652, 0.27525, 0.41177, ...     6
# 9     71741  [0.11461, 0.02715, 0.02721, 0.01836, 0.01516, ...     6
# 11    84459      [0.19799, 0.04886, 0.03096, 0.05607, 0.03729]     5
# 17   173639      [0.04361, 0.02428, 0.19745, 0.00791, 0.07364]     5
# 34     1220      [0.16789, 0.00602, 0.05571, 0.04635, 0.07043]     5
# ..      ...                                                ...   ...
# 79   160518                                          [0.00424]     1
# 80   228549                                            [0.007]     1
# 81   243517                                          [0.00212]     1
# 82   268122                                          [0.00326]     1
# 180  274862                                           [0.0016]     1
#
# [181 rows x 3 columns]
# Reading in files  ['KIRC_run_2.csv', 'KIRC_run_6.csv', 'KIRC_run_4.csv', 'KIRC_run_3.csv', 'KIRC_run_5.csv', 'KIRC_run_0.csv', 'KIRC_run_1.csv', 'KIRC_run_7.csv']
#    feature                                        importances count
# 9   136155  [0.15743, 0.18901, 0.12802, 0.08777, 0.07818, ...     8
# 10  165740  [0.63757, 0.54461, 0.48226, 0.61938, 0.37219, ...     8
# 3       32  [0.00174, 0.00156, 0.00173, 0.00144, 0.00111, ...     6
# 0        4       [0.00235, 0.00234, 0.00194, 0.0015, 0.00244]     5
# 1        7       [0.00127, 0.00126, 0.00105, 0.00081, 0.0011]     5
# 12  258817      [0.02524, 0.02738, 0.06052, 0.00839, 0.07108]     5
# 18  174357      [0.04302, 0.00968, 0.03525, 0.01835, 0.01065]     5
# 5     4315      [0.07335, 0.06358, 0.04208, 0.03242, 0.02451]     5
# 7    83129               [0.00973, 0.00514, 0.00502, 0.00431]     4
# 8   132638                [0.01308, 0.0506, 0.01457, 0.03444]     4
# 19      10                          [0.0017, 0.00042, 0.0012]     3
# 24  226833                        [0.08539, 0.30241, 0.47469]     3
# 23  216548                        [0.02753, 0.07341, 0.04024]     3
# 31   80338                                  [0.0129, 0.02049]     2
# 30     201                                 [0.00135, 0.00086]     2
# 29     121                                 [0.00052, 0.00127]     2
# 2       16                                 [0.00053, 0.00034]     2
# 22   11963                                 [0.16171, 0.08714]     2
# 45   69154                                  [0.06809, 0.0506]     2
# 6    57054                                 [0.01802, 0.02928]     2
# 37  212907                                          [0.01545]     1
# 42  175962                                          [0.00528]     1
# 39  277378                                          [0.05361]     1
# 40  277568                                          [0.01706]     1
# 41      14                                          [0.00012]     1
# 52  100645                                          [0.01176]     1
# 53  121700                                          [0.05803]     1
# 51   49205                                            [7e-05]     1
# 46      23                                          [0.00095]     1
# 43    4046                                          [0.04654]     1
# 44   15797                                          [0.00618]     1
# 50   34225                                          [0.00687]     1
# 49     309                                          [0.00221]     1
# 48     173                                          [0.00189]     1
# 47      47                                           [0.0005]     1
# 38  262200                                          [0.00599]     1
# 27  276715                                          [0.01926]     1
# 36  177541                                          [0.00374]     1
# 35   64612                                          [0.03886]     1
# 4       89                                          [0.00135]     1
# 11  239637                                          [0.00699]     1
# 13  271379                                          [0.05134]     1
# 14     106                                            [9e-05]     1
# 15   40784                                          [0.01097]     1
# 16   87918                                          [0.02053]     1
# 17  141674                                           [0.1008]     1
# 20      18                                          [0.00192]     1
# 21    2627                                          [0.00098]     1
# 25  256581                                          [0.00364]     1
# 26  274054                                          [0.01367]     1
# 28  277154                                          [0.05756]     1
# 32   87241                                          [0.00658]     1
# 33   94725                                          [0.10691]     1
# 34       0                                          [0.00157]     1
# 54  135979                                          [0.00516]     1
# Reading in files  ['KIRP_run_1.csv', 'KIRP_run_5.csv', 'KIRP_run_4.csv', 'KIRP_run_6.csv', 'KIRP_run_2.csv', 'KIRP_run_3.csv', 'KIRP_run_0.csv', 'KIRP_run_7.csv']
#    feature                      importances count
# 12  244098  [0.75323, 0.8808, 1.0, 0.02986]     4
# 0      182      [0.05127, 0.05127, 0.05127]     3
# 5      276      [0.04621, 0.05127, 0.04621]     3
# 31   42169               [0.88079, 0.88079]     2
# 14    3843               [0.02122, 0.03215]     2
# 25  217107                        [0.00201]     1
# 26  226597                        [0.04259]     1
# 27  250250                        [0.02123]     1
# 28  258554                         [0.0131]     1
# 29   20676                        [0.03215]     1
# 30   39074                        [0.02122]     1
# 32  118084                        [0.01457]     1
# 33   61055                        [0.02122]     1
# 23  140518                        [0.09207]     1
# 34  116850                        [0.01457]     1
# 35     942                        [0.05907]     1
# 36   11945                        [0.02973]     1
# 37   13761                        [0.03677]     1
# 38   24903                        [0.75323]     1
# 39   25930                        [0.01397]     1
# 40  238162                         [0.0243]     1
# 41  248083                        [0.01667]     1
# 24  155640                        [0.06185]     1
# 21   85172                         [0.1425]     1
# 22  130958                        [0.00299]     1
# 10  152670                        [0.02973]     1
# 2     9729                        [0.02122]     1
# 3    28879                        [0.01457]     1
# 4   165573                        [0.88079]     1
# 6     1335                        [0.05907]     1
# 7     8036                        [0.03677]     1
# 8    28840                         [0.0243]     1
# 9   122188                        [0.01397]     1
# 11  155943                        [0.02004]     1
# 1     4684                        [0.03215]     1
# 13  270666                        [0.01668]     1
# 15    6522                        [0.03215]     1
# 16   78673                        [0.01456]     1
# 17       0                        [0.00015]     1
# 18    6759                        [0.00469]     1
# 19    9191                        [0.46464]     1
# 20   12042                        [0.12232]     1
# 42  265066                        [0.02004]     1
# Reading in files  ['LIHC_run_4.csv', 'LIHC_run_5.csv', 'LIHC_run_3.csv', 'LIHC_run_7.csv', 'LIHC_run_6.csv', 'LIHC_run_0.csv', 'LIHC_run_2.csv', 'LIHC_run_1.csv']
#     feature                                        importances count
# 19   276097  [0.12262, 0.30685, 0.39188, 0.0122, 0.03888, 0...     8
# 14   240311  [0.05644, 0.05077, 0.01184, 0.11421, 0.07688, ...     8
# 12   216005  [0.22789, 0.23603, 0.03929, 0.24523, 0.44632, ...     8
# 17   251017  [0.01684, 0.02533, 0.02857, 0.04352, 0.13652, ...     6
# 42   266966      [0.00927, 0.00712, 0.05711, 0.01357, 0.01234]     5
# ..      ...                                                ...   ...
# 47    16535                                          [0.00205]     1
# 45       29                                          [0.02517]     1
# 44       20                                          [0.00363]     1
# 43   276322                                          [0.01284]     1
# 121  260611                                          [0.00582]     1
#
# [122 rows x 3 columns]
# Reading in files  ['LUAD_run_3.csv', 'LUAD_run_5.csv', 'LUAD_run_2.csv', 'LUAD_run_7.csv', 'LUAD_run_0.csv', 'LUAD_run_6.csv', 'LUAD_run_1.csv', 'LUAD_run_4.csv']
#    feature                                        importances count
# 7   188113  [0.77691, 0.35916, 0.77692, 0.23529, 0.77691, ...     8
# 18  179173       [0.1394, 0.06027, 0.17821, 0.16634, 0.46562]     5
# 16   94660               [0.06303, 0.03385, 0.04325, 0.02729]     4
# 0      556                        [0.07319, 0.07319, 0.07318]     3
# 13   40160                        [0.05477, 0.01648, 0.05318]     3
# ..     ...                                                ...   ...
# 31   76058                                          [0.01797]     1
# 30    9147                                          [0.01317]     1
# 29    3915                                          [0.03463]     1
# 28  274019                                          [0.01774]     1
# 84  219205                                          [0.02065]     1
#
# [85 rows x 3 columns]
# Reading in files  ['LUSC_run_3.csv', 'LUSC_run_7.csv', 'LUSC_run_5.csv', 'LUSC_run_1.csv', 'LUSC_run_2.csv', 'LUSC_run_0.csv', 'LUSC_run_4.csv', 'LUSC_run_6.csv']
#    feature                                    importances count
# 13  235615    [0.20856, 0.13735, 0.71702, 0.034, 0.45419]     5
# 12  205571  [0.02396, 0.01829, 0.07988, 0.01559, 0.04436]     5
# 26   14963                    [0.08651, 0.23473, 0.05398]     3
# 19       0                    [0.01249, 0.00011, 0.00746]     3
# 58  111392                    [0.19557, 0.12521, 0.02489]     3
# ..     ...                                            ...   ...
# 34  173950                                      [0.04298]     1
# 33  169019                                      [0.01015]     1
# 32  164108                                      [0.02367]     1
# 31  161714                                      [0.00283]     1
# 90  272191                                      [0.06112]     1
#
# [91 rows x 3 columns]
# Reading in files  ['PRAD_run_6.csv', 'PRAD_run_0.csv', 'PRAD_run_2.csv', 'PRAD_run_5.csv', 'PRAD_run_4.csv', 'PRAD_run_3.csv', 'PRAD_run_7.csv', 'PRAD_run_1.csv']
#     feature                                        importances count
# 61     6934  [0.02081, 0.00508, 0.01722, 0.01071, 0.00787, ...     6
# 67    42958  [0.11217, 0.06426, 0.07491, 0.05546, 0.13963, ...     6
# 121  154975      [0.09955, 0.19286, 0.34867, 0.14022, 0.04506]     5
# 34   144256      [0.00665, 0.00601, 0.00323, 0.00926, 0.00885]     5
# 26    88841        [0.13897, 0.008, 0.02522, 0.02339, 0.04682]     5
# ..      ...                                                ...   ...
# 133    1066                                          [0.02339]     1
# 134    1203                                           [0.0006]     1
# 136   17093                                          [0.00549]     1
# 137   19703                                          [0.00064]     1
# 317  245905                                          [0.24897]     1
#
# [318 rows x 3 columns]
# Reading in files  ['THCA_run_0.csv', 'THCA_run_4.csv', 'THCA_run_6.csv', 'THCA_run_5.csv', 'THCA_run_2.csv', 'THCA_run_7.csv', 'THCA_run_3.csv', 'THCA_run_1.csv']
#     feature                                        importances count
# 12    96380  [0.06663, 0.09092, 0.06407, 0.06349, 0.07459, ...     8
# 26   272171  [0.37728, 0.38583, 0.2971, 0.44353, 0.2231, 0....     7
# 2      6406  [0.03759, 0.29022, 0.02201, 0.01823, 0.01826, ...     7
# 13   100477  [0.00891, 0.05374, 0.01036, 0.00801, 0.008, 0....     7
# 5     10485  [0.00752, 0.00037, 0.00078, 0.00378, 0.01005, ...     6
# ..      ...                                                ...   ...
# 62   167977                                          [0.01014]     1
# 61   144056                                          [0.00268]     1
# 60   114538                                          [0.01511]     1
# 59   113649                                          [0.01045]     1
# 178  262788                                          [0.00345]     1
#
# [179 rows x 3 columns]
# Reading in files  ['UCEC_run_5.csv', 'UCEC_run_2.csv', 'UCEC_run_4.csv', 'UCEC_run_1.csv', 'UCEC_run_3.csv', 'UCEC_run_0.csv', 'UCEC_run_6.csv', 'UCEC_run_7.csv', 'UCEC_run_8.csv']
#    feature                                        importances count
# 19  213559  [0.1218, 0.17924, 0.01227, 0.05303, 0.1579, 0....     7
# 13   82601  [0.14544, 0.19161, 0.02976, 0.11783, 0.11912, ...     7
# 1        2         [0.00117, 0.00155, 0.0036, 0.0003, 0.0024]     5
# 0        1                [0.00025, 0.0002, 0.00036, 0.00129]     4
# 27   90870               [0.01777, 0.21661, 0.03858, 0.06218]     4
# ..     ...                                                ...   ...
# 38  111245                                          [0.00532]     1
# 37   72578                                          [0.00785]     1
# 36   47471                                          [0.01211]     1
# 34  213485                                          [0.00373]     1
# 95  262001                                          [0.05081]     1
#
# [96 rows x 3 columns]
