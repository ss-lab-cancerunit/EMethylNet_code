# %% [markdown]
# # View all cms together

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import Image

img = Image.open('confusion_matrix_xgboost_BRCA.svg')
# img=mpimg.imread('confusion_matrix_xgboost_BRCA.svg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-c358de08e4bc> in <module>
#       3 import matplotlib.image as mpimg
#       4
# ----> 5 import Image
#       6
#       7 img = Image.open('confusion_matrix_xgboost_BRCA.svg')
#
# ModuleNotFoundError: No module named 'Image'

# %%
from IPython.display import SVG, display
def display_img(names):
    for name in names:
        print(name)
        display(SVG(name))

import os

names = os.listdir()
names = [name for name in names if 'confusion_matrix' in name and '.svg' in name]
display_img(names)
# Out:
# confusion_matrix_xgboost_BLCA.svg
# confusion_matrix_xgboost_BRCA.svg
# confusion_matrix_xgboost_COAD.svg
# confusion_matrix_xgboost_HNSC.svg
# confusion_matrix_xgboost_ESCA.svg
# confusion_matrix_xgboost_KIRC.svg
# confusion_matrix_xgboost_LUAD.svg
# confusion_matrix_xgboost_THCA.svg
# confusion_matrix_xgboost_PRAD.svg
# confusion_matrix_xgboost_KIRP.svg
# confusion_matrix_xgboost_LIHC.svg
# confusion_matrix_xgboost_.svg
# confusion_matrix_xgboost_LUSC.svg
# confusion_matrix_xgboost_UCEC.svg
